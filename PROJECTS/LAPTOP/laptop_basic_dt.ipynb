# %%
import pandas as pd
import joblib as jb                  # Use to import or save a model

# %%
df=pd.read_csv("laptopPrice.csv")    # Read a file
df
# Out:
#       brand processor_brand  ... Number of Ratings Number of Reviews
# 0      ASUS           Intel  ...                 3                 0
# 1    Lenovo           Intel  ...                65                 5
# 2    Lenovo           Intel  ...                 8                 1
# 3      ASUS           Intel  ...                 0                 0
# 4      ASUS           Intel  ...                 0                 0
# ..      ...             ...  ...               ...               ...
# 818    ASUS             AMD  ...                 0                 0
# 819    ASUS             AMD  ...                 0                 0
# 820    ASUS             AMD  ...                 0                 0
# 821    ASUS             AMD  ...                 0                 0
# 822  Lenovo             AMD  ...                18                 4
#
# [823 rows x 19 columns]

# %%
df.head() # Default 5 rows from start
# Out:
#     brand processor_brand  ... Number of Ratings Number of Reviews
# 0    ASUS           Intel  ...                 3                 0
# 1  Lenovo           Intel  ...                65                 5
# 2  Lenovo           Intel  ...                 8                 1
# 3    ASUS           Intel  ...                 0                 0
# 4    ASUS           Intel  ...                 0                 0
#
# [5 rows x 19 columns]

# %%
df.info()   # Information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
#  16  rating             823 non-null    object
#  17  Number of Ratings  823 non-null    int64
#  18  Number of Reviews  823 non-null    int64
# dtypes: int64(3), object(16)
# memory usage: 122.3+ KB

# %%
df.describe() # Information of numerical data
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.tail() # Default 5 rows from end
# Out:
#       brand processor_brand  ... Number of Ratings Number of Reviews
# 818    ASUS             AMD  ...                 0                 0
# 819    ASUS             AMD  ...                 0                 0
# 820    ASUS             AMD  ...                 0                 0
# 821    ASUS             AMD  ...                 0                 0
# 822  Lenovo             AMD  ...                18                 4
#
# [5 rows x 19 columns]

# %%
df.dtypes # Datatype
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.shape   # Shape of dataset
# Out:
# (823, 19)

# %%
df.columns  # Shows features of the dataset
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
num_columns=df.select_dtypes(exclude='O')    # For numerical data
num_columns
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [823 rows x 3 columns]

# %%
cat_columns=df.select_dtypes(include='O')    # For categorial data
cat_columns
# Out:
#       brand processor_brand processor_name  ... Touchscreen msoffice   rating
# 0      ASUS           Intel        Core i3  ...          No       No  2 stars
# 1    Lenovo           Intel        Core i3  ...          No       No  3 stars
# 2    Lenovo           Intel        Core i3  ...          No       No  3 stars
# 3      ASUS           Intel        Core i5  ...          No       No  3 stars
# 4      ASUS           Intel   Celeron Dual  ...          No       No  3 stars
# ..      ...             ...            ...  ...         ...      ...      ...
# 818    ASUS             AMD        Ryzen 9  ...          No       No  3 stars
# 819    ASUS             AMD        Ryzen 9  ...          No       No  3 stars
# 820    ASUS             AMD        Ryzen 9  ...          No       No  3 stars
# 821    ASUS             AMD        Ryzen 9  ...          No       No  3 stars
# 822  Lenovo             AMD        Ryzen 5  ...          No       No  4 stars
#
# [823 rows x 16 columns]

# %% [markdown]
# we can only train model on numerical data

# %%
cat_columns.head()
# Out:
#     brand processor_brand processor_name  ... Touchscreen msoffice   rating
# 0    ASUS           Intel        Core i3  ...          No       No  2 stars
# 1  Lenovo           Intel        Core i3  ...          No       No  3 stars
# 2  Lenovo           Intel        Core i3  ...          No       No  3 stars
# 3    ASUS           Intel        Core i5  ...          No       No  3 stars
# 4    ASUS           Intel   Celeron Dual  ...          No       No  3 stars
#
# [5 rows x 16 columns]

# %%
num_columns.head()
# Out:
#    Price  Number of Ratings  Number of Reviews
# 0  34649                  3                  0
# 1  38999                 65                  5
# 2  39999                  8                  1
# 3  69990                  0                  0
# 4  26990                  0                  0

# %%
cat_columns["brand"].unique()   # Unique value
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
cat_columns["brand"].nunique()    # No of unique value
# Out:
# 8

# %%
cat_columns['brand']     # Particular column
# Out:
# 0        ASUS
# 1      Lenovo
# 2      Lenovo
# 3        ASUS
# 4        ASUS
#         ...
# 818      ASUS
# 819      ASUS
# 820      ASUS
# 821      ASUS
# 822    Lenovo
# Name: brand, Length: 823, dtype: object

# %%
cat_columns["processor_brand"].unique()    # Unique value
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
cat_columns["processor_brand"].nunique()
# Out:
# 3

# %%
cat_columns["processor_name"].unique()    # Unique value
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
cat_columns["processor_name"].nunique()
# Out:
# 11

# %%
cat_columns["processor_gnrtn"].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
cat_columns["processor_gnrtn"].nunique()
# Out:
# 8

# %%
cat_columns["ram_gb"].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
cat_columns["ram_gb"].nunique()
# Out:
# 4

# %%
cat_columns["ram_type"].unique()
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3'],
#       dtype=object)

# %%
cat_columns["ram_type"].nunique()
# Out:
# 6

# %%
cat_columns["ssd"].unique()
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
cat_columns["ssd"].nunique()
# Out:
# 7

# %%
cat_columns["hdd"].unique()
# Out:
# array(['1024 GB', '0 GB', '512 GB', '2048 GB'], dtype=object)

# %%
cat_columns["hdd"].nunique()
# Out:
# 4

# %%
cat_columns["os"].nunique()
# Out:
# 3

# %%
cat_columns["os_bit"].unique()
# Out:
# array(['64-bit', '32-bit'], dtype=object)

# %%
cat_columns["os_bit"].nunique()
# Out:
# 2

# %%
cat_columns.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'rating'],
#       dtype='object')

# %%
cat_columns["graphic_card_gb"].unique()
# Out:
# array(['0 GB', '2 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
cat_columns["graphic_card_gb"].nunique()
# Out:
# 5

# %%
cat_columns["weight"].unique()
# Out:
# array(['Casual', 'ThinNlight', 'Gaming'], dtype=object)

# %%
cat_columns["weight"].nunique()
# Out:
# 3

# %%
cat_columns["warranty"].unique()
# Out:
# array(['No warranty', '1 year', '2 years', '3 years'], dtype=object)

# %%
cat_columns["warranty"].nunique()
# Out:
# 4

# %%
cat_columns["Touchscreen"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
cat_columns["Touchscreen"].nunique()
# Out:
# 2

# %%
cat_columns["msoffice"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
cat_columns["msoffice"].nunique()
# Out:
# 2

# %%
cat_columns["rating"].unique()
# Out:
# array(['2 stars', '3 stars', '4 stars', '5 stars', '1 star'], dtype=object)

# %%
cat_columns["rating"].nunique()
# Out:
# 5

# %%
cat_columns['brand'].value_counts()   # Count value in particular feature
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
apple=df[df['brand']=="APPLE"]     # Enter into particular brand
apple
# Out:
#      brand processor_brand  ... Number of Ratings Number of Reviews
# 309  APPLE           Intel  ...                32                 5
# 310  APPLE           Intel  ...               108                13
# 407  APPLE           Intel  ...                31                 3
# 408  APPLE           Intel  ...                91                 5
# 599  APPLE              M1  ...              6725               629
# 600  APPLE              M1  ...               640                70
# 601  APPLE              M1  ...                45                 4
# 602  APPLE              M1  ...               640                70
# 603  APPLE              M1  ...               640                70
# 604  APPLE              M1  ...                45                 4
# 605  APPLE              M1  ...              6725               629
# 606  APPLE              M1  ...               640                70
# 607  APPLE              M1  ...               399                45
# 608  APPLE              M1  ...               809                91
# 609  APPLE              M1  ...               809                91
# 610  APPLE              M1  ...              6725               629
# 611  APPLE              M1  ...               399                45
# 612  APPLE              M1  ...                45                 4
# 613  APPLE              M1  ...                42                 8
# 614  APPLE              M1  ...                42                 8
# 615  APPLE              M1  ...                45                 4
# 616  APPLE              M1  ...              6725               629
# 617  APPLE              M1  ...               640                70
# 618  APPLE              M1  ...               640                70
# 619  APPLE              M1  ...                42                 8
# 620  APPLE              M1  ...                42                 8
# 621  APPLE              M1  ...                 3                 1
# 622  APPLE              M1  ...                42                 8
#
# [28 rows x 19 columns]

# %%
asus=df[df['brand']=="ASUS"]      # Enter into particular brand
asus
# Out:
#     brand processor_brand  ... Number of Ratings Number of Reviews
# 0    ASUS           Intel  ...                 3                 0
# 3    ASUS           Intel  ...                 0                 0
# 4    ASUS           Intel  ...                 0                 0
# 5    ASUS           Intel  ...                 0                 0
# 6    ASUS           Intel  ...                31                 3
# ..    ...             ...  ...               ...               ...
# 817  ASUS             AMD  ...                 0                 0
# 818  ASUS             AMD  ...                 0                 0
# 819  ASUS             AMD  ...                 0                 0
# 820  ASUS             AMD  ...                 0                 0
# 821  ASUS             AMD  ...                 0                 0
#
# [249 rows x 19 columns]

# %%
apple.head()
# Out:
#      brand processor_brand  ... Number of Ratings Number of Reviews
# 309  APPLE           Intel  ...                32                 5
# 310  APPLE           Intel  ...               108                13
# 407  APPLE           Intel  ...                31                 3
# 408  APPLE           Intel  ...                91                 5
# 599  APPLE              M1  ...              6725               629
#
# [5 rows x 19 columns]

# %%
apple.tail()
# Out:
#      brand processor_brand  ... Number of Ratings Number of Reviews
# 618  APPLE              M1  ...               640                70
# 619  APPLE              M1  ...                42                 8
# 620  APPLE              M1  ...                42                 8
# 621  APPLE              M1  ...                 3                 1
# 622  APPLE              M1  ...                42                 8
#
# [5 rows x 19 columns]

# %%
apple['processor_brand'].unique()
# Out:
# array(['Intel', 'M1'], dtype=object)

# %%
apple_pb=apple[apple['processor_brand']=='M1']
apple_pb
# Out:
#      brand processor_brand  ... Number of Ratings Number of Reviews
# 599  APPLE              M1  ...              6725               629
# 600  APPLE              M1  ...               640                70
# 601  APPLE              M1  ...                45                 4
# 602  APPLE              M1  ...               640                70
# 603  APPLE              M1  ...               640                70
# 604  APPLE              M1  ...                45                 4
# 605  APPLE              M1  ...              6725               629
# 606  APPLE              M1  ...               640                70
# 607  APPLE              M1  ...               399                45
# 608  APPLE              M1  ...               809                91
# 609  APPLE              M1  ...               809                91
# 610  APPLE              M1  ...              6725               629
# 611  APPLE              M1  ...               399                45
# 612  APPLE              M1  ...                45                 4
# 613  APPLE              M1  ...                42                 8
# 614  APPLE              M1  ...                42                 8
# 615  APPLE              M1  ...                45                 4
# 616  APPLE              M1  ...              6725               629
# 617  APPLE              M1  ...               640                70
# 618  APPLE              M1  ...               640                70
# 619  APPLE              M1  ...                42                 8
# 620  APPLE              M1  ...                42                 8
# 621  APPLE              M1  ...                 3                 1
# 622  APPLE              M1  ...                42                 8
#
# [24 rows x 19 columns]

# %%
apple_pb['Touchscreen'].unique()
# Out:
# array(['No'], dtype=object)

# %%
apple_touch=apple_pb[apple_pb['Touchscreen']=='yes']
apple_touch
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
apple.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count      28.000000          28.000000          28.000000
# mean   151707.857143        1207.535714         117.535714
# std     54907.255498        2310.990913         214.853866
# min     85990.000000           3.000000           1.000000
# 25%    104990.000000          42.000000           5.000000
# 50%    132490.000000         253.500000          29.000000
# 75%    179990.000000         640.000000          70.000000
# max    309990.000000        6725.000000         629.000000

# %%
max_apple=apple[apple['Price']==309990]
max_apple
# Out:
#      brand processor_brand  ... Number of Ratings Number of Reviews
# 621  APPLE              M1  ...                 3                 1
#
# [1 rows x 19 columns]

# %%
# apple =intel ,min 8gb, under 1lakh
apple
# Out:
#      brand processor_brand  ... Number of Ratings Number of Reviews
# 309  APPLE           Intel  ...                32                 5
# 310  APPLE           Intel  ...               108                13
# 407  APPLE           Intel  ...                31                 3
# 408  APPLE           Intel  ...                91                 5
# 599  APPLE              M1  ...              6725               629
# 600  APPLE              M1  ...               640                70
# 601  APPLE              M1  ...                45                 4
# 602  APPLE              M1  ...               640                70
# 603  APPLE              M1  ...               640                70
# 604  APPLE              M1  ...                45                 4
# 605  APPLE              M1  ...              6725               629
# 606  APPLE              M1  ...               640                70
# 607  APPLE              M1  ...               399                45
# 608  APPLE              M1  ...               809                91
# 609  APPLE              M1  ...               809                91
# 610  APPLE              M1  ...              6725               629
# 611  APPLE              M1  ...               399                45
# 612  APPLE              M1  ...                45                 4
# 613  APPLE              M1  ...                42                 8
# 614  APPLE              M1  ...                42                 8
# 615  APPLE              M1  ...                45                 4
# 616  APPLE              M1  ...              6725               629
# 617  APPLE              M1  ...               640                70
# 618  APPLE              M1  ...               640                70
# 619  APPLE              M1  ...                42                 8
# 620  APPLE              M1  ...                42                 8
# 621  APPLE              M1  ...                 3                 1
# 622  APPLE              M1  ...                42                 8
#
# [28 rows x 19 columns]

# %%
apple_processor_brand=apple[apple['processor_brand']=='Intel']
apple_processor_brand
# Out:
#      brand processor_brand  ... Number of Ratings Number of Reviews
# 309  APPLE           Intel  ...                32                 5
# 310  APPLE           Intel  ...               108                13
# 407  APPLE           Intel  ...                31                 3
# 408  APPLE           Intel  ...                91                 5
#
# [4 rows x 19 columns]

# %%
apple_ram=apple_processor_brand[apple_processor_brand['ram_gb']=='8 GB']
apple_ram
# Out:
#      brand processor_brand  ... Number of Ratings Number of Reviews
# 309  APPLE           Intel  ...                32                 5
# 310  APPLE           Intel  ...               108                13
#
# [2 rows x 19 columns]

# %%
apple_price=apple_ram[apple_ram['Price']=='100000']
apple_price
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
#asus, processor gen10,ddr3,os windows,graphics=4gb,under=50k
asus
# Out:
#     brand processor_brand  ... Number of Ratings Number of Reviews
# 0    ASUS           Intel  ...                 3                 0
# 3    ASUS           Intel  ...                 0                 0
# 4    ASUS           Intel  ...                 0                 0
# 5    ASUS           Intel  ...                 0                 0
# 6    ASUS           Intel  ...                31                 3
# ..    ...             ...  ...               ...               ...
# 817  ASUS             AMD  ...                 0                 0
# 818  ASUS             AMD  ...                 0                 0
# 819  ASUS             AMD  ...                 0                 0
# 820  ASUS             AMD  ...                 0                 0
# 821  ASUS             AMD  ...                 0                 0
#
# [249 rows x 19 columns]

# %%
asus_processor_name=asus[asus['processor_gnrtn']=='10th']
asus_processor_name
# Out:
#     brand processor_brand  ... Number of Ratings Number of Reviews
# 0    ASUS           Intel  ...                 3                 0
# 3    ASUS           Intel  ...                 0                 0
# 7    ASUS           Intel  ...                 0                 0
# 27   ASUS           Intel  ...                67                 3
# 60   ASUS           Intel  ...                 0                 0
# 70   ASUS           Intel  ...                 0                 0
# 86   ASUS           Intel  ...               990               108
# 89   ASUS           Intel  ...               130                12
# 98   ASUS           Intel  ...              2551               297
# 119  ASUS           Intel  ...              4008               519
# 120  ASUS           Intel  ...              1869               234
# 122  ASUS           Intel  ...              4008               519
# 125  ASUS           Intel  ...              4008               519
# 130  ASUS           Intel  ...                28                 4
# 136  ASUS           Intel  ...                17                 0
# 139  ASUS           Intel  ...              4203               490
# 148  ASUS           Intel  ...                12                 1
# 150  ASUS           Intel  ...              1850               216
# 151  ASUS           Intel  ...                43                 7
# 156  ASUS           Intel  ...                 7                 0
# 165  ASUS           Intel  ...                12                 0
# 169  ASUS           Intel  ...                31                 6
# 180  ASUS           Intel  ...                 0                 0
# 199  ASUS           Intel  ...              1881               241
# 219  ASUS           Intel  ...              3712               412
# 229  ASUS           Intel  ...                35                 2
# 235  ASUS           Intel  ...              3850               378
# 250  ASUS           Intel  ...                45                 3
# 258  ASUS           Intel  ...              1625               152
# 261  ASUS           Intel  ...                 0                 0
# 302  ASUS           Intel  ...                11                 3
# 320  ASUS           Intel  ...                 4                 0
# 380  ASUS           Intel  ...                 0                 0
# 381  ASUS           Intel  ...                 4                 0
# 382  ASUS           Intel  ...                 0                 0
# 386  ASUS           Intel  ...                 0                 0
# 402  ASUS           Intel  ...              1365               137
# 406  ASUS           Intel  ...               187                26
# 409  ASUS           Intel  ...               844               118
# 420  ASUS           Intel  ...              1444               179
# 427  ASUS           Intel  ...                 0                 0
# 430  ASUS           Intel  ...                 0                 0
# 432  ASUS           Intel  ...                 0                 0
# 443  ASUS           Intel  ...                23                 0
# 465  ASUS           Intel  ...                 1                 1
# 485  ASUS           Intel  ...                76                 9
# 486  ASUS           Intel  ...                11                 2
# 541  ASUS           Intel  ...                17                 1
# 546  ASUS           Intel  ...                 9                 0
# 557  ASUS           Intel  ...                 0                 0
# 565  ASUS           Intel  ...                 3                 0
# 566  ASUS           Intel  ...                 0                 0
# 568  ASUS           Intel  ...                 0                 0
# 576  ASUS           Intel  ...                 0                 0
# 577  ASUS           Intel  ...                 0                 0
# 580  ASUS           Intel  ...                25                 4
# 591  ASUS           Intel  ...                 8                 1
# 598  ASUS           Intel  ...                 2                 1
#
# [58 rows x 19 columns]

# %%
asus_processor_name['ram_type'].unique()
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR3', 'LPDDR4X'], dtype=object)

# %%
asus_ram=asus_processor_name[asus_processor_name['ram_type']=='LPDDR3']
asus_ram
# Out:
#     brand processor_brand  ... Number of Ratings Number of Reviews
# 302  ASUS           Intel  ...                11                 3
# 381  ASUS           Intel  ...                 4                 0
# 382  ASUS           Intel  ...                 0                 0
# 386  ASUS           Intel  ...                 0                 0
# 541  ASUS           Intel  ...                17                 1
# 565  ASUS           Intel  ...                 3                 0
# 566  ASUS           Intel  ...                 0                 0
# 568  ASUS           Intel  ...                 0                 0
# 576  ASUS           Intel  ...                 0                 0
#
# [9 rows x 19 columns]

# %%
asus_graphic=asus_ram[asus_ram['graphic_card_gb']=='8 GB']

asus_graphic
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
#ACER,INTEL,8GB,BELOW 512GB,WINDOW,4GB,touch,below70k
acer=df[df['brand']=='acer']
acer
# Out:
#     brand processor_brand  ... Number of Ratings Number of Reviews
# 9    acer             AMD  ...              1946               240
# 10   acer             AMD  ...               259                47
# 11   acer             AMD  ...               425                67
# 31   acer           Intel  ...                 0                 0
# 64   acer           Intel  ...                61                 4
# 161  acer           Intel  ...                 0                 0
# 176  acer           Intel  ...                38                 2
# 196  acer           Intel  ...             10966              1185
# 197  acer           Intel  ...                 1                 1
# 198  acer           Intel  ...                31                 6
# 207  acer           Intel  ...                39                 3
# 210  acer           Intel  ...                14                 3
# 212  acer           Intel  ...                33                 7
# 226  acer           Intel  ...               155                20
# 244  acer           Intel  ...                 6                 0
# 257  acer           Intel  ...                17                 1
# 319  acer           Intel  ...                 0                 0
# 325  acer           Intel  ...                 0                 0
# 328  acer           Intel  ...                 4                 1
# 365  acer           Intel  ...                 0                 0
# 416  acer           Intel  ...                 0                 0
# 417  acer           Intel  ...               253                28
# 419  acer           Intel  ...               118                28
# 425  acer           Intel  ...                73                21
# 428  acer           Intel  ...                 0                 0
# 439  acer           Intel  ...                18                 6
# 441  acer           Intel  ...                30                 6
# 444  acer           Intel  ...                32                 1
# 447  acer           Intel  ...                27                 2
# 448  acer           Intel  ...                 8                 3
# 475  acer           Intel  ...                 8                 0
# 554  acer           Intel  ...                54                 7
# 575  acer           Intel  ...                 4                 0
# 582  acer           Intel  ...              2038               313
# 585  acer           Intel  ...               214                37
# 586  acer           Intel  ...               342                54
# 587  acer           Intel  ...                 0                 0
# 588  acer           Intel  ...                 0                 0
# 628  acer           Intel  ...               465                89
# 645  acer             AMD  ...                11                 2
# 648  acer             AMD  ...                 0                 0
# 674  acer             AMD  ...                 7                 0
# 676  acer             AMD  ...                 0                 0
# 707  acer             AMD  ...               313                39
# 712  acer             AMD  ...                47                 6
# 714  acer             AMD  ...                 6                 1
# 717  acer             AMD  ...                 0                 0
# 761  acer             AMD  ...                 0                 0
# 780  acer             AMD  ...                 0                 0
# 793  acer             AMD  ...               272                36
# 794  acer             AMD  ...               141                24
#
# [51 rows x 19 columns]

# %%
acer_i=acer[acer['processor_brand']=='Intel']
acer_i
# Out:
#     brand processor_brand  ... Number of Ratings Number of Reviews
# 31   acer           Intel  ...                 0                 0
# 64   acer           Intel  ...                61                 4
# 161  acer           Intel  ...                 0                 0
# 176  acer           Intel  ...                38                 2
# 196  acer           Intel  ...             10966              1185
# 197  acer           Intel  ...                 1                 1
# 198  acer           Intel  ...                31                 6
# 207  acer           Intel  ...                39                 3
# 210  acer           Intel  ...                14                 3
# 212  acer           Intel  ...                33                 7
# 226  acer           Intel  ...               155                20
# 244  acer           Intel  ...                 6                 0
# 257  acer           Intel  ...                17                 1
# 319  acer           Intel  ...                 0                 0
# 325  acer           Intel  ...                 0                 0
# 328  acer           Intel  ...                 4                 1
# 365  acer           Intel  ...                 0                 0
# 416  acer           Intel  ...                 0                 0
# 417  acer           Intel  ...               253                28
# 419  acer           Intel  ...               118                28
# 425  acer           Intel  ...                73                21
# 428  acer           Intel  ...                 0                 0
# 439  acer           Intel  ...                18                 6
# 441  acer           Intel  ...                30                 6
# 444  acer           Intel  ...                32                 1
# 447  acer           Intel  ...                27                 2
# 448  acer           Intel  ...                 8                 3
# 475  acer           Intel  ...                 8                 0
# 554  acer           Intel  ...                54                 7
# 575  acer           Intel  ...                 4                 0
# 582  acer           Intel  ...              2038               313
# 585  acer           Intel  ...               214                37
# 586  acer           Intel  ...               342                54
# 587  acer           Intel  ...                 0                 0
# 588  acer           Intel  ...                 0                 0
# 628  acer           Intel  ...               465                89
#
# [36 rows x 19 columns]

# %%
acer_r=acer_i[acer_i['ram_gb']=='8 GB']
acer_r
# Out:
#     brand processor_brand  ... Number of Ratings Number of Reviews
# 31   acer           Intel  ...                 0                 0
# 176  acer           Intel  ...                38                 2
# 196  acer           Intel  ...             10966              1185
# 197  acer           Intel  ...                 1                 1
# 198  acer           Intel  ...                31                 6
# 207  acer           Intel  ...                39                 3
# 210  acer           Intel  ...                14                 3
# 212  acer           Intel  ...                33                 7
# 226  acer           Intel  ...               155                20
# 244  acer           Intel  ...                 6                 0
# 257  acer           Intel  ...                17                 1
# 319  acer           Intel  ...                 0                 0
# 325  acer           Intel  ...                 0                 0
# 328  acer           Intel  ...                 4                 1
# 365  acer           Intel  ...                 0                 0
# 416  acer           Intel  ...                 0                 0
# 417  acer           Intel  ...               253                28
# 419  acer           Intel  ...               118                28
# 425  acer           Intel  ...                73                21
# 428  acer           Intel  ...                 0                 0
# 439  acer           Intel  ...                18                 6
# 441  acer           Intel  ...                30                 6
# 444  acer           Intel  ...                32                 1
# 447  acer           Intel  ...                27                 2
# 448  acer           Intel  ...                 8                 3
#
# [25 rows x 19 columns]

# %%
acer_s=acer_r[acer_r['ssd']>='512 GB']
acer_s
# Out:
#     brand processor_brand  ... Number of Ratings Number of Reviews
# 226  acer           Intel  ...               155                20
# 244  acer           Intel  ...                 6                 0
# 257  acer           Intel  ...                17                 1
# 319  acer           Intel  ...                 0                 0
# 325  acer           Intel  ...                 0                 0
# 328  acer           Intel  ...                 4                 1
# 365  acer           Intel  ...                 0                 0
#
# [7 rows x 19 columns]

# %%
acer_o=acer_s[acer_s['os']=='Windows']
acer_o
# Out:
#     brand processor_brand  ... Number of Ratings Number of Reviews
# 226  acer           Intel  ...               155                20
# 244  acer           Intel  ...                 6                 0
# 257  acer           Intel  ...                17                 1
# 319  acer           Intel  ...                 0                 0
# 325  acer           Intel  ...                 0                 0
# 328  acer           Intel  ...                 4                 1
# 365  acer           Intel  ...                 0                 0
#
# [7 rows x 19 columns]

# %%
acer_g=acer_o[acer_o['graphic_card_gb']=='4 GB']
acer_g
# Out:
#     brand processor_brand  ... Number of Ratings Number of Reviews
# 325  acer           Intel  ...                 0                 0
#
# [1 rows x 19 columns]

# %%
acer_t=acer_g[acer_g['Touchscreen']=='Yes']
acer_t
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
#  16  rating             823 non-null    object
#  17  Number of Ratings  823 non-null    int64
#  18  Number of Reviews  823 non-null    int64
# dtypes: int64(3), object(16)
# memory usage: 122.3+ KB

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              802 non-null    object
#  1   processor_brand    802 non-null    object
#  2   processor_name     802 non-null    object
#  3   processor_gnrtn    802 non-null    object
#  4   ram_gb             802 non-null    object
#  5   ram_type           802 non-null    object
#  6   ssd                802 non-null    object
#  7   hdd                802 non-null    object
#  8   os                 802 non-null    object
#  9   os_bit             802 non-null    object
#  10  graphic_card_gb    802 non-null    object
#  11  weight             802 non-null    object
#  12  warranty           802 non-null    object
#  13  Touchscreen        802 non-null    object
#  14  msoffice           802 non-null    object
#  15  Price              802 non-null    int64
#  16  rating             802 non-null    object
#  17  Number of Ratings  802 non-null    int64
#  18  Number of Reviews  802 non-null    int64
# dtypes: int64(3), object(16)
# memory usage: 125.3+ KB

# %%
df.drop(['rating','Number of Ratings','Number of Reviews'],axis=1,inplace=True)

# %%
df.duplicated().sum() # Check duplicate value
# Out:
# np.int64(16)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       brand processor_brand processor_name  ... Touchscreen msoffice   Price
# 0      ASUS           Intel        Core i3  ...          No       No   34649
# 1    Lenovo           Intel        Core i3  ...          No       No   38999
# 2    Lenovo           Intel        Core i3  ...          No       No   39999
# 3      ASUS           Intel        Core i5  ...          No       No   69990
# 4      ASUS           Intel   Celeron Dual  ...          No       No   26990
# ..      ...             ...            ...  ...         ...      ...     ...
# 818    ASUS             AMD        Ryzen 9  ...          No       No  135990
# 819    ASUS             AMD        Ryzen 9  ...          No       No  144990
# 820    ASUS             AMD        Ryzen 9  ...          No       No  149990
# 821    ASUS             AMD        Ryzen 9  ...          No       No  142990
# 822  Lenovo             AMD        Ryzen 5  ...          No       No   57490
#
# [786 rows x 16 columns]

# %% [markdown]
# ## Now conversion of cat data into num data

# %%
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
encoder=LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 786 entries, 0 to 822
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            786 non-null    object
#  1   processor_brand  786 non-null    object
#  2   processor_name   786 non-null    object
#  3   processor_gnrtn  786 non-null    object
#  4   ram_gb           786 non-null    object
#  5   ram_type         786 non-null    object
#  6   ssd              786 non-null    object
#  7   hdd              786 non-null    object
#  8   os               786 non-null    object
#  9   os_bit           786 non-null    object
#  10  graphic_card_gb  786 non-null    object
#  11  weight           786 non-null    object
#  12  warranty         786 non-null    object
#  13  Touchscreen      786 non-null    object
#  14  msoffice         786 non-null    object
#  15  Price            786 non-null    int64
# dtypes: int64(1), object(15)
# memory usage: 104.4+ KB

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
output=encoder.fit_transform(df['brand'])
output.shape
output
df['brand']=output
df['brand'].unique()
# Out:
# array([1, 5, 7, 2, 4, 3, 6, 0])

# %%
df['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
ouptut=encoder.fit_transform(df['processor_brand'])
output.shape
output
df['processor_brand']=output
df['processor_brand'].unique()
# Out:
# array([1, 5, 7, 2, 4, 3, 6, 0])

# %%
df['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
output=encoder.fit_transform(df['processor_name'])
output.shape
output
df['processor_name']=output
df['processor_name'].unique()
# Out:
# array([ 1,  2,  0,  8,  3,  4,  5,  6,  7,  9, 10])

# %%
df['processor_gnrtn'].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
output=encoder.fit_transform(df['processor_gnrtn'])
output.shape
output
df['processor_gnrtn']=output
df['processor_gnrtn'].unique()
# Out:
# array([0, 7, 1, 4, 5, 6, 3, 2])

# %%
df['ram_gb'].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
output=encoder.fit_transform(df['ram_gb'])
df['ram_gb']=output
df['ram_gb'].unique()
# Out:
# array([2, 3, 0, 1])

# %%
df['ram_type'].unique()
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3'],
#       dtype=object)

# %%
output=encoder.fit_transform(df['ram_type'])
df['ram_type']=output
df['ram_type'].unique()
# Out:
# array([1, 4, 5, 2, 0, 3])

# %%
df['ssd'].unique()
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
ouptut=encoder.fit_transform(df['ssd'])
df['ssd']=output
df['ssd'].unique()
# Out:
# array([1, 4, 5, 2, 0, 3])

# %%
df['hdd'].unique()
# Out:
# array(['1024 GB', '0 GB', '512 GB', '2048 GB'], dtype=object)

# %%
output=encoder.fit_transform(df['hdd'])
df['hdd']=output
df['hdd'].unique()
# Out:
# array([1, 0, 3, 2])

# %%
df['os'].unique()
# Out:
# array(['Windows', 'DOS', 'Mac'], dtype=object)

# %%
output=encoder.fit_transform(df['os'])
df['os']=output
df['os'].unique()
# Out:
# array([2, 0, 1])

# %%
df['graphic_card_gb'].unique()
# Out:
# array(['0 GB', '2 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
output=encoder.fit_transform(df['graphic_card_gb'])
df['graphic_card_gb']=output
df['graphic_card_gb'].unique()
# Out:
# array([0, 1, 2, 3, 4])

# %%
df['weight'].unique()
# Out:
# array(['Casual', 'ThinNlight', 'Gaming'], dtype=object)

# %%
output=encoder.fit_transform(df['weight'])
df['weight']=output
df['weight'].unique()
# Out:
# array([0, 2, 1])

# %%
df['warranty'].unique()
# Out:
# array(['No warranty', '1 year', '2 years', '3 years'], dtype=object)

# %%
output=encoder.fit_transform(df['warranty'])
df['warranty']=output
df['warranty'].unique()
# Out:
# array([3, 0, 1, 2])

# %%
df['os_bit'].unique()
# Out:
# array(['64-bit', '32-bit'], dtype=object)

# %%
output=encoder.fit_transform(df['os_bit'])
df['os_bit']=output
df['os_bit'].unique()
# Out:
# array([1, 0])

# %%
df['Touchscreen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
output=encoder.fit_transform(df['Touchscreen'])
df['Touchscreen']=output
df['Touchscreen'].unique()
# Out:
# array([0, 1])

# %%
df['msoffice'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
output=encoder.fit_transform(df['msoffice'])
df['msoffice']=output
df['msoffice'].unique()
# Out:
# array([0, 1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 786 entries, 0 to 822
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            786 non-null    int64
#  1   processor_brand  786 non-null    int64
#  2   processor_name   786 non-null    int64
#  3   processor_gnrtn  786 non-null    int64
#  4   ram_gb           786 non-null    int64
#  5   ram_type         786 non-null    int64
#  6   ssd              786 non-null    int64
#  7   hdd              786 non-null    int64
#  8   os               786 non-null    int64
#  9   os_bit           786 non-null    int64
#  10  graphic_card_gb  786 non-null    int64
#  11  weight           786 non-null    int64
#  12  warranty         786 non-null    int64
#  13  Touchscreen      786 non-null    int64
#  14  msoffice         786 non-null    int64
#  15  Price            786 non-null    int64
# dtypes: int64(16)
# memory usage: 104.4 KB

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Now split the data

# %%
x=df.drop(['Price'],axis=1)
y=df[['Price']]
y
# Out:
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 818  135990
# 819  144990
# 820  149990
# 821  142990
# 822   57490
#
# [784 rows x 1 columns]

# %%
x
# Out:
#      brand  processor_brand  processor_name  ...  warranty  Touchscreen  msoffice
# 0        1                1               1  ...         3            0         0
# 1        5                5               1  ...         3            0         0
# 2        5                5               1  ...         3            0         0
# 3        1                1               2  ...         3            0         0
# 4        1                1               0  ...         3            0         0
# ..     ...              ...             ...  ...       ...          ...       ...
# 818      1                1              10  ...         0            0         0
# 819      1                1              10  ...         0            0         0
# 820      1                1              10  ...         0            0         0
# 821      1                1              10  ...         0            0         0
# 822      5                5               8  ...         3            0         0
#
# [784 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((627, 15), (157, 15), (627, 1), (157, 1))

# %%
x_train.head()
x_train.shape
# Out:
# (627, 15)

# %%
y_train.head()
y_train.shape
# Out:
# (627, 1)

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  ...  warranty  Touchscreen  msoffice
# 632      1                1               6  ...         3            0         0
# 624      1                1               6  ...         3            1         0
# 218      4                4               2  ...         0            0         1
# 673      4                4               8  ...         0            0         1
# 183      3                3               1  ...         0            0         1
# ..     ...              ...             ...  ...       ...          ...       ...
# 82       3                3               1  ...         0            0         0
# 156      1                1               1  ...         3            0         0
# 347      3                3               2  ...         2            0         0
# 256      4                4               2  ...         0            0         1
# 587      7                7               4  ...         0            0         0
#
# [157 rows x 15 columns]

# %%
y_test
# Out:
#       Price
# 632   27990
# 624   58100
# 218   67990
# 673   48990
# 183   41390
# ..      ...
# 82    48500
# 156   38000
# 347   71990
# 256   66999
# 587  169990
#
# [157 rows x 1 columns]

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### **DECISION TREE**

# %%
from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier

# %%
obj=DecisionTreeRegressor()
obj.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
print("Testing score",obj.score(x_test,y_test))
# Out:
# Testing score 0.49074146298504906

# %%
print("Training score",obj.score(x_train,y_train))
# Out:
# Training score 0.975191971323835

# %%
obj1=DecisionTreeClassifier()
obj1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Testing score",obj1.score(x_test,y_test))
print("Training score",obj1.score(x_train,y_train))
# Out:
# Testing score 0.012738853503184714
# Training score 0.7878787878787878
