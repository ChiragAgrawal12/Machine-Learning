# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Visualize Distributions With Seaborn
#
# As a python library which is used for create a graph ,this is best library for creating the graphs
#
# Seaborn is a library that uses Matplotlib underneath to plot graphs.
# It will be used to visualize random distributions.
#
# Various types of graph in seaborn:-
#
# Relational Plots:
#
# * scatterplot()
# * lineplot()
#
# Categorical Plots:
#
# * stripplot()
# * swarmplot()
# * boxplot()
# * violinplot()
# * boxenplot()
# * pointplot()
# * barplot()
# * countplot()
#
#
# Distribution Plots:
#
# * histplot()
# * kdeplot()
# * ecdfplot()
# * rugplot()
#
# Matrix Plots:
#
# * heatmap()
# * clustermap()
#
# Regression Plots:
#
# * lmplot()
# * regplot()
# * residplot()

# %%
data = sns.load_dataset("tips")                     # data is taken from seaborn directly
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.head()                  # Print top 5 rows as default
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.tail()                      # Print bottom 5 rows as default
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# ## LINEPLOT

# %%
plt.plot(data['total_bill'])                        # Plot data of total_bill in a graph
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.describe()                         # Describes the numeric data of the dataset
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.lineplot(data['total_bill'])              # Print graph using seaborn and provides label too
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# ## SCATTERPLOT

# %%
sns.scatterplot(x= 'total_bill',y = 'tip',data=data)               # Display scatterplot of total_bill and tip
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## HISTPLOT

# %%
sns.histplot(data['total_bill'])                          # Histogram is plotted using seaborn
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
plt.hist(data['total_bill'])                                  # Histogram is plotted using matplotlib
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## KDEPLOT

# %%
sns.kdeplot(data['total_bill'])                        # kdeplot is printed using seaborn
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# catplot= categorial graph
# relplot= ralational graph
# scatterplot= scattered graph

# %% [markdown]
# ## RELATIONAL PLOT( relplot )

# %%
sns.relplot(x= 'total_bill',y= 'tip', data=data)     # Display relplot of tip and total bill

# %%
data['time'].unique()             # Displaying unique values for time
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.relplot(x= 'total_bill',y= 'tip', hue= 'time',data=data)    # Display customers for lunch and dinner with seperate colors and hue is used to show the relation according to the provided variable

# %%
sns.relplot(x= 'total_bill', y= 'tip', hue= 'time', style= 'smoker',data=data)    # With the help of style, people are classified as smoker and no smoker

# %%
sns.relplot(x= 'total_bill', y= 'tip', hue= 'time', style= 'smoker',data=data,kind= 'scatter',col='smoker')  # kind is used for type of plot and col is used to make columns

# %%
sns.relplot(x= 'total_bill', y= 'tip', hue= 'time', style= 'smoker',data=data,kind='scatter',row='time')          # row is used to plot rows

# %%
hii=(data['day']).unique()
hii
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.relplot(x= 'total_bill', y= 'tip', hue= 'time',data=data,kind= 'scatter',col='day')         # Graphs are printed according to day

# %%
sns.relplot(x= 'total_bill', y= 'tip',data=data,)
plt.title("total bill vs tip",fontsize=20,color='blue')           # title of the graph is written
plt.xlabel("total bill",fontsize=20,color='blue')                 # label is provided to x
plt.ylabel("tip",fontsize=20,color='blue')                        # label is provided to y
# Out:
# Text(13.819444444444445, 0.5, 'tip')

# %% [markdown]
# # CATPLOT

# %%
sns.catplot(x='day', y='total_bill',data=data,kind= 'swarm')    # Categorial graph is printed and kind is used for swarm style

# %%
sns.catplot(x='day', y='total_bill',data=data,kind= 'strip')            # Strip plots individual points as scatter along a categorical axis.

# %%
sns.catplot(x='day', y='total_bill',data=data,kind= 'box')          # box display the distribution of numerical data and identify outliers

# %%
sns.catplot(x='day', y='total_bill',data=data,kind= 'bar')   # bar is used used to show comparisons between groups for maximum bill ranges

# %%
sns.catplot(x='day', y='total_bill',data=data,kind= 'violin')    # It shows the distribution of a dataset as violin style

# %%
sns.catplot(x='day', y='total_bill',data=data,kind= 'boxen')  # Improved version of the box plot designed for large datasets,useful when dealing with skewed or highly variable data

# %% [markdown]
# COUNTPLOT()

# %%
plt.Figure(figsize=(5,5))
sns.countplot(data['day'])    # Count the number of customers on each day
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %% [markdown]
# STRIPPLOT()

# %%
sns.stripplot(data['total_bill'])      # Shows the maximum range of total bill
plt.show()

# %% [markdown]
# SWARMPLOT()

# %%
sns.swarmplot(data['total_bill'])      # Shows the maximum range of total bill
plt.show()

# %% [markdown]
# BOXPLOT()

# %%
sns.boxplot(data['total_bill'])      # Shows the maximum range of total bill
plt.show()

# %% [markdown]
# BOXENPLOT()

# %%
sns.boxenplot(data['total_bill'])      # Shows the maximum range of total bill
plt.show()

# %% [markdown]
# VIOLINPLOT()

# %%
sns.violinplot(data['total_bill'])      # Shows the maximum range of total bill
plt.show()

# %% [markdown]
# POINTPLOT()

# %%
sns.pointplot(data['total_bill'])      # Shows the maximum range of total bill
plt.show()

# %% [markdown]
# BARPLOT()

# %%
sns.barplot(data['total_bill'])      # Shows the maximum range of total bill
plt.show()
